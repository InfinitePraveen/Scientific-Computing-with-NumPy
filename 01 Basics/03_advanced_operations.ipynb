# %% [markdown]
# ### Advanced operation with Business examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]
sales_data = np.array([
    [1, 150000, 180000, 220000, 100000], # Paradise Biriyani
    [2, 120000, 140000, 160000, 190000], # Beijing Bites
    [3, 200000, 230000, 260000, 300000], # Pizza Hunb
    [4, 180000, 210000, 240000, 270000], # Burger Point
    [5, 160000, 185000, 205000, 230000]  # Chai Point
])

print("=========Zomato Sales Analysis=========")
print("\n Sales data shape", sales_data.shape)
print("\n Sample data for 1st 3 restaurants:", sales_data[:, 1:])
# Out:
# =========Zomato Sales Analysis=========
#
#  Sales data shape (5, 5)
#
#  Sample data for 1st 3 restaurants: [[150000 180000 220000 100000]
#  [120000 140000 160000 190000]
#  [200000 230000 260000 300000]
#  [180000 210000 240000 270000]
#  [160000 185000 205000 230000]]

# %%
# Total sales per year
print(np.sum(sales_data, axis=0))
yearly_total = (np.sum(sales_data[:, 1:], axis=0))
print(yearly_total)

# Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1)
print(min_sales)

# MAximum sales per year
max_sales = np.max(sales_data[:, 1:], axis=1)
print(max_sales)

# Average sales per restaurants
avg_sales = np.mean(sales_data[:, 1:], axis=1)
print(avg_sales)
# Out:
# [     15  810000  945000 1085000 1090000]
# [ 810000  945000 1085000 1090000]
# [100000 120000 200000 180000 160000]
# [220000 190000 300000 270000 230000]
# [162500. 152500. 247500. 225000. 195000.]

# %%
# Cumulative sales
cumulative_sales = np.cumsum(sales_data[:, 1:], axis=1)
print(cumulative_sales)

plt.figure(figsize=(10, 6))
plt.plot(np.mean(cumulative_sales, axis=0))
plt.title("Average cumulative sales across all the restaurant ")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# [[150000 330000 550000 650000]
#  [120000 260000 420000 610000]
#  [200000 430000 690000 990000]
#  [180000 390000 630000 900000]
#  [160000 345000 550000 780000]]

# %%
vector1 = np.array([1, 2, 3, 4, 5])
vector2 = np.array([6, 7, 8, 9, 10])

print("Vector addition: ", vector1 + vector2)
print("\nMultiplication of vector", vector1 * vector2)
print("\nDot Product:", np.dot(vector1, vector2))

angle = np.arccos(np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2)))
print(angle)
# Out:
# Vector addition:  [ 7  9 11 13 15]
#
# Multiplication of vector [ 6 14 24 36 50]
#
# Dot Product: 130
# 0.26554161733900966

# %%
# Vectorised operation
restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorised_upper = np.vectorize(str.upper)
print("Vectorised Upper", vectorised_upper(restaurant_types))
# Out:
# Vectorised Upper ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
monthly_average = sales_data[:, 1:] / 12
print(monthly_average)
# Out:
# [[12500.         15000.         18333.33333333  8333.33333333]
#  [10000.         11666.66666667 13333.33333333 15833.33333333]
#  [16666.66666667 19166.66666667 21666.66666667 25000.        ]
#  [15000.         17500.         20000.         22500.        ]
#  [13333.33333333 15416.66666667 17083.33333333 19166.66666667]]
